# %%
from numpy import expand_dims
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

import pickle
def open_file(fname):
    pickle_in = open(fname,"rb")
    return pickle.load(pickle_in)

images=open_file('image_data_1ch_1.pkl')

# %%
import matplotlib.pyplot as plt

plt.imshow(images[25],cmap='viridis')
plt.colorbar()

# %%
xtrain = np.ndarray((len(images),182, 3))

# %%
import numpy as np
## Introduce the channel dimention in the input dataset 


## iterate in train and test, add the rgb dimention 
def add_rgb_dimention(array):
    scaler_map = cm.ScalarMappable(cmap="viridis")
    array = scaler_map.to_rgba(array)[:, : -1]
    return array
# for i in range(x_train.shape[0]):
#     xtrain[i] = add_rgb_dimention(x_train[i])
# for i in range(x_test.shape[0]):
#     xtest[i] = add_rgb_dimention(x_test[i])
for i in range(len(images)):
    xtrain[i] = add_rgb_dimention(images[i].flatten())

# %%
rgb_image=xtrain.reshape(-1,13,14,3)

# %%
plt.imshow(rgb_image[1006])
plt.colorbar()

# %%
import pickle as pkl

with open("rgb_image.pkl","wb") as output_file:
    pkl.dump(rgb_image,output_file)

# %%
fig,ax=plt.subplots(2,4,figsize=(10,11))
ax=ax.ravel()
j=0
for i in range(8):
       
    ax[i].imshow(rgb_image[i])
    j=j+100
